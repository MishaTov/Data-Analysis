# %% [markdown]
# <h1>Лабораторна робота 1</h1>
# <h3>Товстоноженко Михайло ФБ-31мп</h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %%
dataset = "SaYoPillow.csv"

# %%
data = pd.read_csv(dataset)

# %%
data.head()
# Out:
#       sr      rr       t      lm      bo    rem   sr.1     hr  sl
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20   3
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76   3
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00   1
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84   3
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12   0

# %%
columns = {'sr':"snoring rate", 'rr':"respiration rate", 'bt':"body temperature", 
           'lm':"limb movement", 'bo':"blood oxygen", 'em':"eye movement", 'sh':"sleeping hours", 
           'hr':"heart rate", 'sl':"stress level"}

# %%
data.columns = columns.values()
data.columns
# Out:
# Index(['snoring rate', 'respiration rate', 'body temperature', 'limb movement',
#        'blood oxygen', 'eye movement', 'sleeping hours', 'heart rate',
#        'stress level'],
#       dtype='object')

# %%
data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6b4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6b4c_level0_col0" class="col_heading level0 col0" >snoring rate</th>
#       <th id="T_b6b4c_level0_col1" class="col_heading level0 col1" >respiration rate</th>
#       <th id="T_b6b4c_level0_col2" class="col_heading level0 col2" >body temperature</th>
#       <th id="T_b6b4c_level0_col3" class="col_heading level0 col3" >limb movement</th>
#       <th id="T_b6b4c_level0_col4" class="col_heading level0 col4" >blood oxygen</th>
#       <th id="T_b6b4c_level0_col5" class="col_heading level0 col5" >eye movement</th>
#       <th id="T_b6b4c_level0_col6" class="col_heading level0 col6" >sleeping hours</th>
#       <th id="T_b6b4c_level0_col7" class="col_heading level0 col7" >heart rate</th>
#       <th id="T_b6b4c_level0_col8" class="col_heading level0 col8" >stress level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6b4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6b4c_row0_col0" class="data row0 col0" >93.800000</td>
#       <td id="T_b6b4c_row0_col1" class="data row0 col1" >25.680000</td>
#       <td id="T_b6b4c_row0_col2" class="data row0 col2" >91.840000</td>
#       <td id="T_b6b4c_row0_col3" class="data row0 col3" >16.600000</td>
#       <td id="T_b6b4c_row0_col4" class="data row0 col4" >89.840000</td>
#       <td id="T_b6b4c_row0_col5" class="data row0 col5" >99.600000</td>
#       <td id="T_b6b4c_row0_col6" class="data row0 col6" >1.840000</td>
#       <td id="T_b6b4c_row0_col7" class="data row0 col7" >74.200000</td>
#       <td id="T_b6b4c_row0_col8" class="data row0 col8" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6b4c_row1_col0" class="data row1 col0" >91.640000</td>
#       <td id="T_b6b4c_row1_col1" class="data row1 col1" >25.104000</td>
#       <td id="T_b6b4c_row1_col2" class="data row1 col2" >91.552000</td>
#       <td id="T_b6b4c_row1_col3" class="data row1 col3" >15.880000</td>
#       <td id="T_b6b4c_row1_col4" class="data row1 col4" >89.552000</td>
#       <td id="T_b6b4c_row1_col5" class="data row1 col5" >98.880000</td>
#       <td id="T_b6b4c_row1_col6" class="data row1 col6" >1.552000</td>
#       <td id="T_b6b4c_row1_col7" class="data row1 col7" >72.760000</td>
#       <td id="T_b6b4c_row1_col8" class="data row1 col8" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6b4c_row2_col0" class="data row2 col0" >60.000000</td>
#       <td id="T_b6b4c_row2_col1" class="data row2 col1" >20.000000</td>
#       <td id="T_b6b4c_row2_col2" class="data row2 col2" >96.000000</td>
#       <td id="T_b6b4c_row2_col3" class="data row2 col3" >10.000000</td>
#       <td id="T_b6b4c_row2_col4" class="data row2 col4" >95.000000</td>
#       <td id="T_b6b4c_row2_col5" class="data row2 col5" >85.000000</td>
#       <td id="T_b6b4c_row2_col6" class="data row2 col6" >7.000000</td>
#       <td id="T_b6b4c_row2_col7" class="data row2 col7" >60.000000</td>
#       <td id="T_b6b4c_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6b4c_row3_col0" class="data row3 col0" >85.760000</td>
#       <td id="T_b6b4c_row3_col1" class="data row3 col1" >23.536000</td>
#       <td id="T_b6b4c_row3_col2" class="data row3 col2" >90.768000</td>
#       <td id="T_b6b4c_row3_col3" class="data row3 col3" >13.920000</td>
#       <td id="T_b6b4c_row3_col4" class="data row3 col4" >88.768000</td>
#       <td id="T_b6b4c_row3_col5" class="data row3 col5" >96.920000</td>
#       <td id="T_b6b4c_row3_col6" class="data row3 col6" >0.768000</td>
#       <td id="T_b6b4c_row3_col7" class="data row3 col7" >68.840000</td>
#       <td id="T_b6b4c_row3_col8" class="data row3 col8" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6b4c_row4_col0" class="data row4 col0" >48.120000</td>
#       <td id="T_b6b4c_row4_col1" class="data row4 col1" >17.248000</td>
#       <td id="T_b6b4c_row4_col2" class="data row4 col2" >97.872000</td>
#       <td id="T_b6b4c_row4_col3" class="data row4 col3" >6.496000</td>
#       <td id="T_b6b4c_row4_col4" class="data row4 col4" >96.248000</td>
#       <td id="T_b6b4c_row4_col5" class="data row4 col5" >72.480000</td>
#       <td id="T_b6b4c_row4_col6" class="data row4 col6" >8.248000</td>
#       <td id="T_b6b4c_row4_col7" class="data row4 col7" >53.120000</td>
#       <td id="T_b6b4c_row4_col8" class="data row4 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6b4c_row5_col0" class="data row5 col0" >56.880000</td>
#       <td id="T_b6b4c_row5_col1" class="data row5 col1" >19.376000</td>
#       <td id="T_b6b4c_row5_col2" class="data row5 col2" >95.376000</td>
#       <td id="T_b6b4c_row5_col3" class="data row5 col3" >9.376000</td>
#       <td id="T_b6b4c_row5_col4" class="data row5 col4" >94.064000</td>
#       <td id="T_b6b4c_row5_col5" class="data row5 col5" >83.440000</td>
#       <td id="T_b6b4c_row5_col6" class="data row5 col6" >6.376000</td>
#       <td id="T_b6b4c_row5_col7" class="data row5 col7" >58.440000</td>
#       <td id="T_b6b4c_row5_col8" class="data row5 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6b4c_row6_col0" class="data row6 col0" >47.000000</td>
#       <td id="T_b6b4c_row6_col1" class="data row6 col1" >16.800000</td>
#       <td id="T_b6b4c_row6_col2" class="data row6 col2" >97.200000</td>
#       <td id="T_b6b4c_row6_col3" class="data row6 col3" >5.600000</td>
#       <td id="T_b6b4c_row6_col4" class="data row6 col4" >95.800000</td>
#       <td id="T_b6b4c_row6_col5" class="data row6 col5" >68.000000</td>
#       <td id="T_b6b4c_row6_col6" class="data row6 col6" >7.800000</td>
#       <td id="T_b6b4c_row6_col7" class="data row6 col7" >52.000000</td>
#       <td id="T_b6b4c_row6_col8" class="data row6 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6b4c_row7_col0" class="data row7 col0" >50.000000</td>
#       <td id="T_b6b4c_row7_col1" class="data row7 col1" >18.000000</td>
#       <td id="T_b6b4c_row7_col2" class="data row7 col2" >99.000000</td>
#       <td id="T_b6b4c_row7_col3" class="data row7 col3" >8.000000</td>
#       <td id="T_b6b4c_row7_col4" class="data row7 col4" >97.000000</td>
#       <td id="T_b6b4c_row7_col5" class="data row7 col5" >80.000000</td>
#       <td id="T_b6b4c_row7_col6" class="data row7 col6" >9.000000</td>
#       <td id="T_b6b4c_row7_col7" class="data row7 col7" >55.000000</td>
#       <td id="T_b6b4c_row7_col8" class="data row7 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b6b4c_row8_col0" class="data row8 col0" >45.280000</td>
#       <td id="T_b6b4c_row8_col1" class="data row8 col1" >16.112000</td>
#       <td id="T_b6b4c_row8_col2" class="data row8 col2" >96.168000</td>
#       <td id="T_b6b4c_row8_col3" class="data row8 col3" >4.224000</td>
#       <td id="T_b6b4c_row8_col4" class="data row8 col4" >95.112000</td>
#       <td id="T_b6b4c_row8_col5" class="data row8 col5" >61.120000</td>
#       <td id="T_b6b4c_row8_col6" class="data row8 col6" >7.112000</td>
#       <td id="T_b6b4c_row8_col7" class="data row8 col7" >50.280000</td>
#       <td id="T_b6b4c_row8_col8" class="data row8 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b6b4c_row9_col0" class="data row9 col0" >55.520000</td>
#       <td id="T_b6b4c_row9_col1" class="data row9 col1" >19.104000</td>
#       <td id="T_b6b4c_row9_col2" class="data row9 col2" >95.104000</td>
#       <td id="T_b6b4c_row9_col3" class="data row9 col3" >9.104000</td>
#       <td id="T_b6b4c_row9_col4" class="data row9 col4" >93.656000</td>
#       <td id="T_b6b4c_row9_col5" c

# %%
data.shape
# Out:
# (630, 9)

# %%
data.isnull().sum()
# Out:
# snoring rate        0
# respiration rate    0
# body temperature    0
# limb movement       0
# blood oxygen        0
# eye movement        0
# sleeping hours      0
# heart rate          0
# stress level        0
# dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
plt.figure(figsize = (8,8))
corr = data.corr()
sns.heatmap(corr, annot = True)
plt.yticks(rotation=0)
plt.show()

# %%
columns
# Out:
# {'sr': 'snoring rate',
#  'rr': 'respiration rate',
#  'bt': 'body temperature',
#  'lm': 'limb movement',
#  'bo': 'blood oxygen',
#  'em': 'eye movement',
#  'sh': 'sleeping hours',
#  'hr': 'heart rate',
#  'sl': 'stress level'}

# %%
cols = ['bt', 'sh', 'hr']
for col in cols:
    sns.histplot(data = data, x = columns[col], color = 'green')
    plt.title(columns[col])
    plt.show()

# %%
sl = columns['sl']
for col in cols:
    plt.figure()
    sns.boxplot(x = sl, y = columns[col], data = data)

# %%
X = data.drop(sl, axis = 1)
y = data[sl]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# <h3>KNN</h3>

# %%
for i in range(1, 30):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Neighours: {i}; Accuracy: {accuracy:.2f}")
# Out:
# Neighours: 1; Accuracy: 1.00
# Neighours: 2; Accuracy: 1.00
# Neighours: 3; Accuracy: 1.00
# Neighours: 4; Accuracy: 1.00
# Neighours: 5; Accuracy: 1.00
# Neighours: 6; Accuracy: 1.00
# Neighours: 7; Accuracy: 1.00
# Neighours: 8; Accuracy: 1.00
# Neighours: 9; Accuracy: 1.00
# Neighours: 10; Accuracy: 1.00
# Neighours: 11; Accuracy: 1.00
# Neighours: 12; Accuracy: 1.00
# Neighours: 13; Accuracy: 1.00
# Neighours: 14; Accuracy: 1.00
# Neighours: 15; Accuracy: 1.00
# Neighours: 16; Accuracy: 1.00
# Neighours: 17; Accuracy: 1.00
# Neighours: 18; Accuracy: 1.00
# Neighours: 19; Accuracy: 1.00
# Neighours: 20; Accuracy: 1.00
# Neighours: 21; Accuracy: 1.00
# Neighours: 22; Accuracy: 1.00
# Neighours: 23; Accuracy: 1.00
# Neighours: 24; Accuracy: 1.00
# Neighours: 25; Accuracy: 1.00
# Neighours: 26; Accuracy: 1.00
# Neighours: 27; Accuracy: 1.00
# Neighours: 28; Accuracy: 1.00
# Neighours: 29; Accuracy: 1.00

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       1.00      1.00      1.00        45
#            2       1.00      1.00      1.00        43
#            3       1.00      1.00      1.00        31
#            4       1.00      1.00      1.00        35
#
#     accuracy                           1.00       189
#    macro avg       1.00      1.00      1.00       189
# weighted avg       1.00      1.00      1.00       189

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[35  0  0  0  0]
#  [ 0 45  0  0  0]
#  [ 0  0 43  0  0]
#  [ 0  0  0 31  0]
#  [ 0  0  0  0 35]]

# %% [markdown]
# <h3>Decision Tree</h3>

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.99

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        35
#            1       0.96      1.00      0.98        45
#            2       1.00      1.00      1.00        43
#            3       1.00      1.00      1.00        31
#            4       1.00      1.00      1.00        35
#
#     accuracy                           0.99       189
#    macro avg       0.99      0.99      0.99       189
# weighted avg       0.99      0.99      0.99       189

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[33  2  0  0  0]
#  [ 0 45  0  0  0]
#  [ 0  0 43  0  0]
#  [ 0  0  0 31  0]
#  [ 0  0  0  0 35]]

# %% [markdown]
# <h3>SVM</h3>

# %%
svc = SVC()
grid_params = {'kernel': ['rbf', 'linear', 'poly'],'C': [0.01, 0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001]}
grid_search = GridSearchCV(svc, grid_params)
grid_search.fit(X_train, y_train)
clf = grid_search.best_estimator_
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       1.00      1.00      1.00        45
#            2       1.00      1.00      1.00        43
#            3       1.00      1.00      1.00        31
#            4       1.00      1.00      1.00        35
#
#     accuracy                           1.00       189
#    macro avg       1.00      1.00      1.00       189
# weighted avg       1.00      1.00      1.00       189

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[35  0  0  0  0]
#  [ 0 45  0  0  0]
#  [ 0  0 43  0  0]
#  [ 0  0  0 31  0]
#  [ 0  0  0  0 35]]

# %% [markdown]
# <h3>Random Forest</h3>

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       1.00      1.00      1.00        45
#            2       1.00      1.00      1.00        43
#            3       1.00      1.00      1.00        31
#            4       1.00      1.00      1.00        35
#
#     accuracy                           1.00       189
#    macro avg       1.00      1.00      1.00       189
# weighted avg       1.00      1.00      1.00       189

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[35  0  0  0  0]
#  [ 0 45  0  0  0]
#  [ 0  0 43  0  0]
#  [ 0  0  0 31  0]
#  [ 0  0  0  0 35]]

# %% [markdown]
# <h3>Ada Boost</h3>

# %%
clf = AdaBoostClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.52

# %%
print(classification_report(y_test, y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        35
#            1       1.00      0.00      0.00        45
#            2       1.00      0.00      0.00        43
#            3       0.26      1.00      0.41        31
#            4       1.00      1.00      1.00        35
#
#     accuracy                           0.52       189
#    macro avg       0.85      0.59      0.48       189
# weighted avg       0.88      0.52      0.43       189

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[33  0  0  2  0]
#  [ 0  0  0 45  0]
#  [ 0  0  0 43  0]
#  [ 0  0  0 31  0]
#  [ 0  0  0  0 35]]
